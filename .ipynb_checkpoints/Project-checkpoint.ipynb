# %% [markdown]
# # Introduction:
#
# In this project we will work with the Human Development Indicator, an indicator that measures the human development of the countries. It is made up of three dimensions: educational level, health level and income level of the population.
#
#
# In my opinion, this is an insufficient description of human development, so I will add more dimensions to the index an see how it affects the current ranking.
#
# *Dimensions are described in Dataframes Section.

# %% [markdown]
# # Data Sources:
# In this project we will obtain our data from two different open sources, the first one is Gapminder's repository and the second one is CTdata360's repository.
#
# Gapminder is an independent Swedish foundation with no political, religious or economic affiliations. Gapminder is a fact tank, not a think tank. Gapminder fights devastating misconceptions about global development. Gapminder produces free teaching resources making the world understandable based on reliable statistics. Gapminder promotes a fact-based worldview everyone can understand.  Gapminder collaborates with universities, UN, public agencies and non-governmental organizations. All Gapminder activities are governed by the board.
# _https://www.gapminder.org/about-gapminder/_
#
# **Gapminder's dataframes:**
#
# - _Human Development Index_
# - _Population_
# - _Gross National Income_
# - _Gender Equality Index_
# - _CO2 Emissions_
# - _Fundamental Rights_
# - _Murders/100k people_
#
# *Data link: _https://www.gapminder.org/data/_
#
# TCdata360 is an initiative of the World Bank Group's Macroeconomics, Trade & Investment Global Practice, which helps countries achieve the Bank Group's twin goals, ending extreme poverty and boosting shared prosperity, through rapid and broad-based economic growth, centered on strong contributions from the private sector.
# _https://tcdata360.worldbank.org_
#
# **TCdata360's dataframes:**
#
# - _Press Freedom Index_
#
# *Data link: _https://tcdata360.worldbank.org/indicators/h3f86901f?country=BRA&indicator=32416&viz=line_chart&years=2001,2019_

# %% [markdown]
# # Dataframes:
#
#
# 1. **Human Development Index (hdi):**
#
#     Index used to rank countries by level of "human development". It contains three dimensions: *health level*, *educational level* and *living standard*.
#
#     - Value Range: 0 to 1 (at higher values greater, human development)
#     - Country Range: 187 countries
#     - Year Range: 1990-2015 (27)
#
#
# 2. **Population (pop):**
#
#     Total population.
#
#     - Country Range: 195 countries
#     - Year Range: 1800-2100 (prediction) (302)
#
#
# 3. **Gross National Income per capita (gni):**
#
#     Gross National Income divided by midyear population. Data are in constant 2010 U.S. dollars.
#
#     - Country Range: 155 countries
#     - Year Range: 1975-2018 (45)
#
#
# 4. **Gender Equality Index (gender_equality):**
#
#     Contains five dimensions: *power distribution by gender*, *female participation in civil society organizations*, *ratio between female and male mean years of schooling*, *proportion of lower chamber female legislators* and *proportion of women in ministerial level positions*.
#
#     - Value Range: 0 to 100 (at higher values, greater gender equality)
#     - Country Range: 186 countries
#     - Year Range: 1960-2017 (59)
#
#
# 5. **CO2 Emissions (emissions):**
#
#     Carbon dioxide emissions from burning of fossil fuels (metric tonnes of CO2 per person).
#
#     - Values: higher values are obviously worse
#     - Country Range: 192 countries
#     - Year Range: 1800-2014 (216)
#
#
# 6. **Fundamental Rights (fundrights):**
#
#     It includes three subattributes: *acces to justice*,*civil liberties*, and *social rights and equality*
#
#     - Value Range: 0 to 100 (at higher values, more fundamental rights are respected by the country)
#     - Country Range: 155 countries
#     - Year Range: 1975-2018 (45)
#
#
# 7. **Murders/100k people (murders):**
#
#     Mortality due to interpersonal violence, per 100,000 standard population, age adjusted. This rate is calculated as if all countries had the same age composition of the population.
#
#     - Values: higher values are obviously worse
#     - Country Range: 103 countries
#     - Year Range: 1950-2016 (68)
#
#
# 8. **Press Freedom Index (press_freedom):**
#
#     The data is collected through an online questionnaire sent to journalists, media lawyers, researchers and other media specialists selected by Reporters without Borders (RSF).
#
#     - Values: 0 to 100 (at higher values, the country has a freer press)
#     - Country Range: 180 countries
#     - Year Range: 2001-2019 (18)

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from functools import reduce
import cufflinks as cf
from ipywidgets import interact
import chart_studio.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
cf.go_offline()
import plotly.express as px
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Import datasets

# %%
hdi = pd.read_csv('hdi.csv')
pop = pd.read_csv('population_total.csv')
gni = pd.read_csv('gni_per_capita.csv')
gender_equality = pd.read_csv('gender_idea.csv')
emissions = pd.read_csv('co2_emissions.csv')
fundrights = pd.read_csv('fundright_idea.csv')
murders = pd.read_csv('murder_per_100000_people.csv')
press_freedom = pd.read_csv('press_freedom.csv')

# All csv's are in the project folder.

# %% [markdown]
# # Data quick view:
#
# We take a look at our dataframes and then we draw some quick graphs to understand the data and their distributions. As they are time series, we choose one year  to plot the graphs (2014, because is common in all dataframes).

# %%
# Human Development Index:
hdi.head(2)
# Out:
#        country   1990   1991   1992   1993   1994   1995   1996   1997   1998  \
# 0  Afghanistan  0.295  0.300  0.309  0.305  0.300  0.324  0.328  0.332  0.335
# 1      Albania  0.635  0.618  0.603  0.608  0.616  0.628  0.637  0.636  0.646
#
#    ...   2006   2007   2008   2009   2010   2011   2012   2013   2014   2015
# 0  ...  0.415  0.433  0.434  0.448  0.454  0.463  0.470  0.476  0.479  0.479
# 1  ...  0.703  0.713  0.721  0.725  0.738  0.752  0.759  0.761  0.762  0.764
#
# [2 rows x 27 columns]

# %%
sns.set(rc={'figure.figsize':(11,6)})
sns.distplot(hdi['2014'], 20, color='lightcoral', axlabel='HDI Histogram (2014)')

# %%
# Population:
pop.head(2)
# Out:
#        country     1800     1801     1802     1803     1804     1805     1806  \
# 0  Afghanistan  3280000  3280000  3280000  3280000  3280000  3280000  3280000
# 1      Albania   400000   402000   404000   405000   407000   409000   411000
#
#       1807     1808  ...      2091      2092      2093      2094      2095  \
# 0  3280000  3280000  ...  76600000  76400000  76300000  76100000  76000000
# 1   413000   414000  ...   1330000   1300000   1270000   1250000   1220000
#
#        2096      2097      2098      2099      2100
# 0  75800000  75600000  75400000  75200000  74900000
# 1   1190000   1170000   1140000   1110000   1090000
#
# [2 rows x 302 columns]

# %%
# We range the plot up to 100 million people for a nicer visualization.
plt.hist(pop['2014'],bins=10, range=(0,1e8), color='lightcoral')  
plt.ylabel('Count')
plt.xlabel('Population')
plt.title('Population Histogram (2014)')
plt.show()

# %% [markdown]
# Pareto

# %%
# Gross National Income per capita:
gni.head(2)
# Out:
#        country  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  \
# 0  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1      Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#      2008    2009  2010    2011    2012    2013    2014    2015    2016  \
# 0   447.0   527.0   555   576.0   640.0   643.0   636.0   626.0   625.0
# 1  3790.0  3870.0  4050  4210.0  4240.0  4390.0  4440.0  4570.0  4740.0
#
#      2017
# 0     NaN
# 1  4900.0
#
# [2 rows x 59 columns]

# %%
plt.hist(gni['2014'],bins=20, color='lightcoral')  
plt.ylabel('Count')
plt.xlabel('GNI/c')
plt.title('GNI/c Histogram (2014)')
plt.show()
# Out:
# /Users/plopezbar/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning:
#
# invalid value encountered in greater_equal
#
# /Users/plopezbar/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning:
#
# invalid value encountered in less_equal

# %% [markdown]
# Pareto

# %%
# Gender Equality Index:
gender_equality.head(2)
# Out:
#        country  1975  1976  1977  1978  1979  1980  1981  1982  1983  ...  \
# 0  Afghanistan   4.0   4.0   4.0   1.0  12.0  12.0  12.0  12.0  12.0  ...
# 1      Albania  50.0  53.0  53.0  58.0  58.0  58.0  58.0  57.0  57.0  ...
#
#    2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# 0  32.0  32.0    32    32    34    34    34    32    34    35
# 1  53.0  54.0    53    53    59    59    59    59    62    68
#
# [2 rows x 45 columns]

# %%
sns.distplot(gender_equality['2014'], 20, color='lightcoral', axlabel='Gender Equality Histogram (2014)')

# %%
# CO2 Emissions per capita:
emissions.head(2)
# Out:
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1      Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#      2005    2006    2007   2008   2009   2010   2011  2012   2013   2014
# 0  0.0529  0.0637  0.0854  0.154  0.242  0.294  0.412  0.35  0.316  0.299
# 1  1.3800  1.2800  1.3000  1.460  1.480  1.560  1.790  1.68  1.730  1.960
#
# [2 rows x 216 columns]

# %%
plt.hist(emissions['2014'],bins=15, color='lightcoral')  
plt.ylabel('Count')
plt.xlabel('CO2/c')
plt.title('CO2 Emissions per capita Histogram (2014)')
plt.show()

# %% [markdown]
# Pareto

# %%
# Fundamental Rights Index:
fundrights.head(2)
# Out:
#        country  1975  1976  1977  1978  1979  1980  1981  1982  1983  ...  \
# 0  Afghanistan  31.0  31.0  31.0  27.0  25.0  26.0  27.0  26.0  27.0  ...
# 1      Albania  20.0  20.0  20.0  20.0  21.0  20.0  21.0  20.0  20.0  ...
#
#    2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# 0  39.0  38.0    38    39    38    38    38    36    37    36
# 1  68.0  68.0    68    68    69    69    69    69    69    68
#
# [2 rows x 45 columns]

# %%
sns.distplot(fundrights['2014'], 20, color='lightcoral', axlabel='Fundamental Rights Histogram (2014)')

# %%
# Murders/100k people:
murders.head(2)
# Out:
#                country  1950  1951  1952  1953  1954  1955  1956  1957  1958  \
# 0              Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  Antigua and Barbuda   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  ...  3.07  2.96   NaN   2.3   NaN   NaN   NaN   NaN   NaN   NaN
# 1  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [2 rows x 68 columns]

# %%
plt.hist(murders['2014'],bins=15, color='lightcoral')  
plt.ylabel('Count')
plt.xlabel('Murders/100k pop')
plt.title('Murders/100k pop Histogram (2014)')
plt.show()

# %%
# Press Freedom Index:
press_freedom.head(2)
# Out:
#   Country ISO3 Country Name  Indicator Id            Indicator  \
# 0          AFG  Afghanistan         32416  Press Freedom Index
# 1          AFG  Afghanistan         32417   Press Freedom Rank
#
#   Subindicator Type  2001   2002   2003   2004   2005  ...    2008    2009  \
# 0             Total  35.5  40.17  28.25  39.17  44.25  ...   54.25   51.67
# 1             Total  59.0  78.00  49.00  62.00  67.00  ...  103.00  105.00
#
#      2012    2013    2014    2015   2016    2017    2018    2019
# 0   37.36   37.07   37.44   37.75    NaN   39.46   37.28   36.55
# 1  112.00  117.00  116.00  114.00  114.0  120.00  118.00  121.00
#
# [2 rows x 22 columns]

# %%
# rename 'Country Name' column to 'country':
press_freedom = press_freedom.rename(columns={"Country Name": "country"})

# filter the df by even rows, odd ones contain a rank not an index:
press_freedom = press_freedom.iloc[::2].reset_index()

# drop columns we don't need:
press_freedom = press_freedom.drop(['index', 'Country ISO3', 'Indicator Id', 'Indicator', 'Subindicator Type'], axis=1)

# %%
press_freedom.head(2)
# Out:
#        country  2001   2002   2003   2004   2005  2006   2007   2008   2009  \
# 0  Afghanistan  35.5  40.17  28.25  39.17  44.25  56.5  59.25  54.25  51.67
# 1       Angola  30.2  28.00  26.50  18.00  21.50  26.5  29.50  36.50  28.50
#
#     2012   2013   2014   2015  2016   2017   2018   2019
# 0  37.36  37.07  37.44  37.75   NaN  39.46  37.28  36.55
# 1  37.80  36.50  37.84  39.89   NaN  40.42  38.35  34.96

# %%
plt.hist(press_freedom['2014'],bins=15,range=(0,100), color='lightcoral')  
plt.ylabel('Count')
plt.xlabel('Press Freedom Index')
plt.title('Press Freedom Index Histogram (2014)')
plt.show()

# %% [markdown]
# # Data cleaning and manipulation
#
#
# Once we've seen the dataframes, we want to clean and transform them to obtain a single dataframe with all indicators by year and country.

# %%
#First, we'll get the countries all of them share:
countries_in_common = list(set.intersection(*map(set, [hdi.country, pop.country, gni.country, gender_equality.country, 
                                                       emissions.country, fundrights.country, murders.country, press_freedom.country])))
print(countries_in_common)
# Out:
# ['Latvia', 'Colombia', 'Hungary', 'Cuba', 'South Africa', 'Romania', 'Costa Rica', 'Kuwait', 'Estonia', 'Turkey', 'Azerbaijan', 'Tajikistan', 'Lithuania', 'Jordan', 'Nicaragua', 'Oman', 'Slovenia', 'Greece', 'Ukraine', 'Cyprus', 'Thailand', 'Qatar', 'Argentina', 'Jamaica', 'Turkmenistan', 'Japan', 'Mongolia', 'Australia', 'Bahrain', 'Belarus', 'Norway', 'Kyrgyz Republic', 'New Zealand', 'Slovak Republic', 'Serbia', 'El Salvador', 'Guatemala', 'Finland', 'Uzbekistan', 'Italy', 'Sweden', 'Germany', 'France', 'Panama', 'Armenia', 'Mauritius', 'Poland', 'Malaysia', 'Uruguay', 'Czech Republic', 'Austria', 'Kazakhstan', 'Tunisia', 'Singapore', 'Dominican Republic', 'Georgia', 'Israel', 'Canada', 'Netherlands', 'Trinidad and Tobago', 'Croatia', 'Sri Lanka', 'Peru', 'Ecuador', 'Denmark', 'Brazil', 'Switzerland', 'Philippines', 'Belgium', 'Chile', 'Albania', 'Ireland', 'Portugal', 'Mexico', 'Spain', 'Bosnia and Herzegovina', 'United States', 'Bulgaria', 'United Kingdom', 'Moldova']

# %%
# We print the shape of our dataframes to check a transformation later:
df_list = [hdi, pop, gni, gender_equality, emissions, fundrights, murders, press_freedom]
[i.shape for i in df_list]
# Out:
# [(187, 27),
#  (195, 302),
#  (186, 59),
#  (155, 45),
#  (192, 216),
#  (155, 45),
#  (103, 68),
#  (180, 18)]

# %%
# As we can see at the dataframes description, the years in common are the following:
years_in_commmon = '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009','2012', '2013', '2014'

# %%
# We'll use this function in our transformation:
def clean_dataframes (df):
    
    #We subset the dataframe by the countries all datasets have in common:
    df = df[df['country'].isin(countries_in_common)]
    
    #We subset the dataframe by years in common (2001-2014), 2010 and 2011 excepcions:
    df = df[['country','2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009','2012', '2013', '2014']]
    
    return df

# %%
df_list = [df.pipe(clean_dataframes) for df in df_list]

# %%
hdi = df_list[0]
pop = df_list[1]
gni = df_list[2]
gender_equality = df_list[3]
emissions = df_list[4]
fundrights = df_list[5]
murders = df_list[6]
press_freedom = df_list[7]

# %%
#We test the adjustment by checking the shapes:
indices= [hdi, pop, gni, gender_equality, emissions, fundrights, murders, press_freedom]
[i.shape for i in indices]
# Out:
# [(80, 13),
#  (80, 13),
#  (80, 13),
#  (80, 13),
#  (80, 13),
#  (80, 13),
#  (80, 13),
#  (80, 13)]

# %% [markdown]
# # Data normalization:
# We want to normalize all our variables so the range of the values is consistent, this normalization can make statistical analysis easier down the road. We want to transform all values into the range 0-1, the same as our reference indicator (hdi).

# %% [markdown]
# ## Method One: Normalization dividing by 100:

# %%
# The next dataframes have their values in range 0-100, we just divide by 100 then.
ls =[gender_equality, fundrights, press_freedom]

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
for i in ls:
    for c in [c for c in i.columns if i[c].dtype in numerics]:
        i[c] = i[c].div(100).round(2)

# %%
# We check normalization:
gender_equality.head(2)
# Out:
#      country  2001  2002  2003  2004  2005  2006  2007  2008  2009  2012  \
# 1    Albania  0.48  0.48  0.48  0.49  0.52  0.52  0.52  0.52  0.53  0.53
# 4  Argentina  0.67  0.67  0.69  0.70  0.70  0.70  0.79  0.79  0.79  0.81
#
#    2013  2014
# 1  0.59  0.59
# 4  0.72  0.72

# %%
fundrights.head(2)
# Out:
#      country  2001  2002  2003  2004  2005  2006  2007  2008  2009  2012  \
# 1    Albania  0.66  0.66  0.66  0.67  0.67  0.68  0.68  0.68  0.68  0.68
# 4  Argentina  0.69  0.69  0.69  0.69  0.70  0.70  0.71  0.71  0.70  0.71
#
#    2013  2014
# 1  0.69  0.69
# 4  0.68  0.68

# %%
press_freedom.head(2)
# Out:
#      country  2001  2002    2003  2004  2005  2006  2007  2008  2009  2012  \
# 2    Albania   NaN  0.06    0.12  0.14  0.18  0.26  0.16  0.22  0.22  0.31
# 5  Argentina  0.12  0.15  358.26  0.14  0.17  0.25  0.14  0.11  0.16  0.26
#
#    2013  2014
# 2  0.30  0.29
# 5  0.25  0.26

# %% [markdown]
# ## Method Two: Normalization type Min-Max:

# %%
# We normalize next dfs by subtracting the MIN and dividing by MAX minus MIN:
ls =[gni, emissions, murders]

# %%
for i in ls:
    for c in [c for c in i.columns if i[c].dtype in numerics]:
        i[c] = ((i[c]-i[c].min())/(i[c].max()-i[c].min())).round(2)

# %%
# We check normalization:
gni.head(2)
# Out:
#      country  2001  2002  2003  2004  2005  2006  2007  2008  2009  2012  \
# 1    Albania  0.03  0.03  0.03  0.03  0.03  0.03  0.03  0.03  0.04  0.04
# 5  Argentina  0.09  0.07  0.08  0.08  0.09  0.09  0.10  0.10  0.10  0.11
#
#    2013  2014
# 1  0.04  0.04
# 5  0.11  0.10

# %%
emissions.head(2)
# Out:
#      country  2001  2002  2003  2004  2005  2006  2007  2008  2009  2012  \
# 1    Albania  0.01  0.01  0.02  0.02  0.02  0.01  0.02  0.02  0.03  0.03
# 6  Argentina  0.05  0.05  0.05  0.07  0.06  0.06  0.07  0.09  0.09  0.10
#
#    2013  2014
# 1  0.03  0.03
# 6  0.11  0.09

# %%
murders.head(2)
# Out:
#      country  2001  2002  2003  2004  2005  2006  2007  2008  2009  2012  \
# 0    Albania  0.47  0.54  0.36  0.44   NaN   NaN  0.39  0.25   NaN   NaN
# 2  Argentina   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2013  2014
# 0   NaN   NaN
# 2   NaN   NaN

# %% [markdown]
# # Unpivot Dataframes and merge:

# %%
#We follow our process unpivoting our dataframes:
hdi = hdi.melt(id_vars=['country'], var_name='year', value_name='hdi')
pop = pop.melt(id_vars=['country'], var_name='year', value_name='pop')
gni = gni.melt(id_vars=['country'], var_name='year', value_name='gni')
gender_equality = gender_equality.melt(id_vars=['country'], var_name='year', value_name='gender_equality')
emissions = emissions.melt(id_vars=['country'], var_name='year', value_name='emissions')
fundrights = fundrights.melt(id_vars=['country'], var_name='year', value_name='fundrights')
murders = murders.melt(id_vars=['country'], var_name='year', value_name='murders')
press_freedom = press_freedom.melt(id_vars=['country'], var_name='year', value_name='press_freedom')

# %%
# Output: Exemple 1 (hdi)
hdi.head(2)
# Out:
#      country  year    hdi
# 0    Albania  2001  0.670
# 1  Argentina  2001  0.776

# %%
# Check shape
hdi.shape
# Out:
# (960, 3)

# %%
# Output: Exemple 2 (press_freedom)
press_freedom.head(2)
# Out:
#      country  year  press_freedom
# 0    Albania  2001            NaN
# 1  Argentina  2001           0.12

# %%
# Shapes match
press_freedom.shape
# Out:
# (960, 3)

# %%
# We finally create our joined dataframe containing all indicators:
dfs = [gni, gender_equality, emissions, fundrights, murders, press_freedom]
df = hdi
r = 3
for i in dfs:
    df[r] = i.iloc[:,2]
    r+=1
df.columns = ['country', 'year', 'hdi', 'gni', 'gender_equality', 'emissions', 'fundrights', 'murders', 'press_freedom']

# %%
df.head()
# Out:
#      country  year    hdi   gni  gender_equality  emissions  fundrights  \
# 0    Albania  2001  0.670  0.03             0.48       0.01        0.66
# 1  Argentina  2001  0.776  0.09             0.67       0.05        0.69
# 2    Armenia  2001  0.645  0.01             0.37       0.01        0.56
# 3  Australia  2001  0.902  0.52             0.76       0.25        0.88
# 4    Austria  2001  0.847  0.50             0.70       0.12        0.90
#
#    murders  press_freedom
# 0     0.47            NaN
# 1      NaN           0.12
# 2     0.09            NaN
# 3     0.08           0.04
# 4     0.03           0.08

# %%
# Our df shape should be 960 rows (80 countries * 12 years) by 9 columns:
df.shape
# Out:
# (960, 9)

# %% [markdown]
# # Data Analysis and Visualization:
#
# At this point, we will analyze the correlations between indicators and we'll see which are the best candidates to add them to the HDI, thus increasing its dimensions.

# %%
# Correlation dataframe:
corr = df.corr()
corr
# Out:
#                       hdi       gni  gender_equality  emissions  fundrights  \
# hdi              1.000000  0.825669         0.542971   0.408027    0.737137
# gni              0.825669  1.000000         0.539919   0.520365    0.691157
# gender_equality  0.542971  0.539919         1.000000  -0.080220    0.810633
# emissions        0.408027  0.520365        -0.080220   1.000000    0.073082
# fundrights       0.737137  0.691157         0.810633   0.073082    1.000000
# murders         -0.487953 -0.498973        -0.156192  -0.199615   -0.340716
# press_freedom   -0.005015 -0.025083         0.009455  -0.016544   -0.004368
#
#                   murders  press_freedom
# hdi             -0.487953      -0.005015
# gni             -0.498973      -0.025083
# gender_equality -0.156192       0.009455
# emissions       -0.199615      -0.016544
# fundrights      -0.340716      -0.004368
# murders          1.000000       0.301727
# press_freedom    0.301727       1.000000

# %%
# With this interactive graph we can plot each correlation: try hdi-gni.
@interact
def correlations(column1=list(df.select_dtypes('number').columns),
                 column2=list(df.select_dtypes('number').columns)):
    print(f"Correlation: {df[column1].corr(df[column2])}")
    sns.jointplot(column1, column2, data=df, color='darkgreen')
# Out:
# interactive(children=(Dropdown(description='column1', options=('hdi', 'gni', 'gender_equality', 'emissions', '…

# %%
df.corrwith(df['hdi']).sort_values()
# Out:
# murders           -0.487953
# press_freedom     -0.005015
# emissions          0.408027
# gender_equality    0.542971
# fundrights         0.737137
# gni                0.825669
# hdi                1.000000
# dtype: float64

# %% [markdown]
# We can say most correlated indicators are gni, fundrights, gender_equality and murders (-).

# %%
# We plot a correlation matrix:
mask = np.triu(np.ones_like(corr, dtype=np.bool))
cmap = sns.diverging_palette(275, 150, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=2, annot=True)

# %% [markdown]
# Since emissions and murders are negative indicators, we can adjust them to be positive so we can generate an index easily.

# %%
df['emissions_adjusted'] = df.apply(lambda row: 1 - row.emissions, axis = 1)
df['murders_adjusted'] = df.apply(lambda row: 1 - row.murders, axis = 1)

#drop unadjusted columns:
df = df.drop(['emissions', 'murders'], axis=1)

# %%
df.head(2)
# Out:
#      country  year    hdi   gni  gender_equality  fundrights  press_freedom  \
# 0    Albania  2001  0.670  0.03             0.48        0.66            NaN
# 1  Argentina  2001  0.776  0.09             0.67        0.69           0.12
#
#    emissions_adjusted  murders_adjusted
# 0                0.99              0.53
# 1                0.95               NaN

# %% [markdown]
# To generate our new indicator on the HDI, two things must be taken into consideration:
#
# 1. Based on the correlations between variables, we must discard the GNI and the fundrights indicators as they both have a high correlation with the HDI, also in the case of the fundrights, it is also highly correlated with gender_equality, so it is better to stick with gender_equality which has a lower correlation with the HDI.
#
#
# 2. We will weigh all the variables with the same weight (one seventh), taking into account that the HDI itself is made up of 3 variables, we will give it a weight of 3/7.

# %%
# We generate the new dimensioned IDH called global_hdi:
df['global_hdi'] = df.apply(lambda row: (3*row.hdi/7)+(row.gender_equality/7)+(row.press_freedom/7)+(row.emissions_adjusted/7)+(row.murders_adjusted/7),
                            axis= 1)
df.head()
# Out:
#      country  year    hdi   gni  gender_equality  fundrights  press_freedom  \
# 0    Albania  2001  0.670  0.03             0.48        0.66            NaN
# 1  Argentina  2001  0.776  0.09             0.67        0.69           0.12
# 2    Armenia  2001  0.645  0.01             0.37        0.56            NaN
# 3  Australia  2001  0.902  0.52             0.76        0.88           0.04
# 4    Austria  2001  0.847  0.50             0.70        0.90           0.08
#
#    emissions_adjusted  murders_adjusted  global_hdi
# 0                0.99              0.53         NaN
# 1                0.95               NaN         NaN
# 2                0.99              0.91         NaN
# 3                0.75              0.92    0.739429
# 4                0.88              0.97    0.738714

# %%
# We observe correlation with hdi:
df = df[['country','year','hdi','global_hdi']]
corr = df.corr()
corr
# Out:
#                 hdi  global_hdi
# hdi         1.00000     0.81645
# global_hdi  0.81645     1.00000

# %%
px.scatter(df, x='hdi', y='global_hdi', color='country', title='Correlation hdi - global_hdi')
# Out:
# <div>
#
#
#             <div id="cfddcac8-d67b-4f03-9bd9-d1de84abe551" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cfddcac8-d67b-4f03-9bd9-d1de84abe551")) {
#                     Plotly.newPlot(
#                         'cfddcac8-d67b-4f03-9bd9-d1de84abe551',
# ...

# %%
# We add population to the df to plot an interactive graph:
df['pop'] = pop['pop']
df.head(2)
# Out:
#      country  year    hdi  global_hdi       pop
# 0    Albania  2001  0.670         NaN   3130000
# 1  Argentina  2001  0.776         NaN  37300000

# %%
# We plot the correlation between hdi and global_hdi for our years range (01-14):
px.scatter(df, x='hdi', y='global_hdi', animation_frame='year',
          animation_group='country', size='pop', color='country', 
          hover_name='country', size_max=45 )
# Out:
# <div>
#
#
#             <div id="275b5ae4-d4cb-4d28-bdad-4e31afb7801d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("275b5ae4-d4cb-4d28-bdad-4e31afb7801d")) {
#                     Plotly.newPlot(
#                         '275b5ae4-d4cb-4d28-bdad-4e31afb7801d',
# ...
